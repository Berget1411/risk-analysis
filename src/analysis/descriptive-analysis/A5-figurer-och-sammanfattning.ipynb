# %% [markdown]
# # A.5 Sammanfattning av deskriptiv analys

# %% [markdown]
# ## Slutsatser
#
# - **Datakvalitet** (A1): Inga saknade värden, Duration i (0, 1], konsistenta kategorinivåer
# - **Skador är sällsynta** (A2): ~98 % nollskador, ~0,021 skador per exponerat år
# - **Test liknar träning** (A2): Samma skadefrekvens i 2025 som 2021–2024
# - **Verksamhet** (A3): VVS och Takarbeten högst, Målare och Elektriker lägst
# - **Geografi** (A3): Storstad högst, Småstad lägst
# - **Tid** (A3): Svag uppåttrend, ej dramatisk
# - **Duration** (A3): Stabil frekvens per exponerat år → offset, inte förklaringsvariabel
# - **Korrelation** (A4): Omsättning och Försäkringsbelopp bär liknande information
# - **Storlek** (A4): Monoton trend — större företag har högre skadefrekvens
# - **Interaktioner** (A3): Mestadels additiva effekter, VVS × Storstad extra hög

# %% [markdown]
# ## Figurer och tabeller för rapporten
#
# | Figur/tabell | Notebook | Beskrivning |
# |---|---|---|
# | Skadefrekvens-sammanfattning | A2 | Andel 0/1/2 skador, frekvens per exponerat år |
# | Numerisk sammanfattning | A2 | Medel, Std, Q1, Median, Q3, IQR, P99, Max |
# | Histogram log-transformerade variabler | A2 | 2×2 subplot |
# | Stapeldiagram per verksamhet | A3 | Barplot sorterat efter frekvens |
# | Stapeldiagram per geografi | A3 | Barplot sorterat efter frekvens |
# | Linjediagram över tid | A3 | Frekvens per år |
# | Heatmap Verksamhet × Geografi | A3 | Annoterad heatmap |
# | Korrelationsmatris | A4 | Pearson rå + log |
# | Decilanalys | A4 | Storlek vs skadefrekvens |
